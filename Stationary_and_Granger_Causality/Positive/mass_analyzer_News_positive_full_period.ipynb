# %%
import pandas as pd
import numpy as np
from pathlib import Path
import os
import statsmodels.api as sm
from statsmodels.tsa.stattools import grangercausalitytests
from statsmodels.tsa.api import VAR
import statistics
import matplotlib.pyplot as plt
import datetime
import warnings
from statsmodels.tsa.stattools import adfuller
from sklearn.preprocessing import StandardScaler


# Ignore all warnings
warnings.filterwarnings('ignore')

# If you specifically want to ignore warnings from pandas, you can do so as follows
warnings.filterwarnings('ignore', category=UserWarning, module='pandas')


# Set options to display all columns
pd.set_option('display.max_columns', None)

# Optionally, set the display width to ensure that pandas does not wrap text
pd.set_option('display.width', None)

# Set the column display length to maximum
pd.set_option('display.max_colwidth', None)

# %%
def granger_test(filename, granger_test_data):
    
    global lag
    
    try:
        gc_test = grangercausalitytests(granger_test_data, maxlag=lag, verbose=False)

        # Initialize an empty list to store F test p-values
        f_test_p_values = []
        chi2_test_p_values = []

        # Iterate through the Granger causality test results to extract the F test p-values
        for lag in range(1, lag+1):
            p_value_f = gc_test[lag][0]['ssr_ftest'][1]  # Extracting the p-value
            p_value_chi = gc_test[lag][0]['ssr_chi2test'][1]  # Extracting the p-value
            f_test_p_values.append(round(p_value_f,5))
            chi2_test_p_values.append(round(p_value_chi,5))

        return f_test_p_values, chi2_test_p_values, True
    except:
        # In case of an exception, return lists of 1's of length equal to `lag`
        # print(f"File '{filename}' Granger analysis failed.")
        return [1] * lag, [1] * lag, False

def data_transformer(data):

    data = data.sort_values(by='Date')
    data = data.reset_index(drop=True)
        
    # Update the DataFrame's column names
    new_columns = [col.replace(" - Realtime", "") for col in data.columns]
    data.columns = new_columns
    
    for column in data.select_dtypes(include=['object']).columns:
    # Replace "," with "." in the entire column and convert the column to float
        if column != "Date":
            data[column] = data[column].str.replace(",", ".").astype(float)
    
    
    #Make the modifications for the analysis
    data = data.dropna(subset=["(R1) Close", "News Positive Sentiment Count", "News Negative Sentiment Count"])
    
    # data["News Sentiment Count"] = data["News Positive Sentiment Count"] - data["News Negative Sentiment Count"]    
    # data = data[data['News Sentiment Count'] != 0]
    
    
    #Drop the rows where the News Sentiment Count is 0 because the % change is not calculable at these values
    
    data['Log Returns'] = np.log(data['(R1) Close'] / data['(R1) Close'].shift(1))
    data['Log Returns Variance'] = data['Log Returns'] ** 2
    #data['Log Returns Variance'] = np.absolute(data['Log Returns'])
    
    
    # data['Daily Sentiment Change'] = data['News Sentiment Count'].pct_change()
    
    
    #CHANGE!
    # data['Daily Sentiment Change'] = data['News Publication Count (L1)'].pct_change()
    # data['Daily Sentiment Change'] = data["News Positive Sentiment Count"] / data['News Publication Count (L1)']
    data['Daily Sentiment Change'] = data["News Positive Sentiment Count"] / data['News Publication Count (L1)']*100
    

    data = data.replace(np.inf, 0)
    data = data.dropna(subset=["Daily Sentiment Change", "Log Returns"])
    
    scaler = StandardScaler()
    try:
        data['Log Returns Variance'] = scaler.fit_transform(data['Log Returns Variance'].values.reshape(-1,1))
        data['Daily Sentiment Change'] = scaler.fit_transform(data['Daily Sentiment Change'].values.reshape(-1,1))
    except:
        pass
    
    return data
    

def extract_irf_data(irf):
    global round_value
    global round_value
    
    # Get standard errors of the impulse response functions
    std_errors = irf.stderr()

    # Calculate lower 5% significance value
    lower_5_significance = irf.irfs -1.96* std_errors  # Assuming normal distribution
    #10%-os szorzó ennyi lenne   1.645
    irf_array=irf.irfs
    # Number of time periods is length of the array - 1
    time_periods = len(irf_array) - 1
    
    # Initialize lists to hold the IRF data for each variable's response
    lr_to_lr = [] # Log Returns Variance → Log Returns Variance
    ds_to_lr = []  # Daily Sentiment Change → Log Returns Variance
    lr_to_ds = [] # Log Returns Variance → Daily Sentiment Change
    ds_to_ds = []  # Daily Sentiment Change → Daily Sentiment Change

    # Extract data for each time period
    for t in range(0, time_periods + 1):  # start from 1 to skip the immediate response
        
        lr_to_lr.append(round(irf_array[t][0][0],round_value))
        ds_to_lr.append(round(irf_array[t][0][1],round_value))
        lr_to_ds.append(round(irf_array[t][1][0],round_value))
        ds_to_ds.append(round(irf_array[t][1][1],round_value))
        
    # Initialize lists to hold the IRF lower 5% sigificance data for each variable's response
    lr_to_lr_lower = [] # Log Returns Variance → Log Returns Variance
    ds_to_lr_lower = []  # Daily Sentiment Change → Log Returns Variance
    lr_to_ds_lower = [] # Log Returns Variance → Daily Sentiment Change
    ds_to_ds_lower = []  # Daily Sentiment Change → Daily Sentiment Change
    
    # Extract data for each time period
    for t in range(0, time_periods + 1):  # start from 1 to skip the immediate response
        lr_to_lr_lower.append(round(lower_5_significance[t][0][0],round_value))
        ds_to_lr_lower.append(round(lower_5_significance[t][0][1],round_value))
        lr_to_ds_lower.append(round(lower_5_significance[t][1][0],round_value))
        ds_to_ds_lower.append(round(lower_5_significance[t][1][1],round_value))

    # Combine the lists into a tuple
    irf_data_tuple = (lr_to_lr, ds_to_lr, lr_to_ds, ds_to_ds)
    irf_lower_data_tuple=(lr_to_lr_lower, ds_to_lr_lower, lr_to_ds_lower, ds_to_ds_lower)
    
    return irf_data_tuple,irf_lower_data_tuple

def irf_analysis(data, irf_len):
    global lag
    
    # Prepare the dataset for VAR model
    var_data = data[['Log Returns Variance', 'Daily Sentiment Change']].dropna()

    # Create the VAR model
    model = VAR(var_data)
    try:
        model_fitted = model.fit(maxlags=lag, ic='aic')
        impulse_response_data = model_fitted.irf(irf_len)
        irf_data,irf_lower_data=extract_irf_data(impulse_response_data)
    except:
        return None,None
    return irf_data,irf_lower_data

# %%
cwd = Path.cwd()
filename = "S&P500.xlsx"
file_path = cwd.parent / filename

sp500_data = pd.read_excel(file_path)
sp500 = sp500_data["Ticker"]
sp500 = sp500.str.replace("/", "_")

#Módosítás_1
#Itt lehet beállítani a főbb paramétereket a program futtatásához

#A granger okság számításához használt maximális lag
lag = 10

#Az a szignifikancia szint, ami felett elfogadjuk a granger okságot
threshold = 0.01

#Az impulzus válasz függvény lag-jainak száma
length_of_irf = 25

#Az ábrázolni kívánt chartok száma az IRF ábrázolásnál. Ha csak 2 paraméter között vizsgálunk, akkor 4 chart kell
number_of_charts = 4

#A módusz kerekítési értéke (hány tizedes)
round_value = 8

# Az IRF ábrázolásnál mennyi középső értéket tartunk meg a min és max értékek leválasztása előtt
keep_value = 0.8  # Example keep value, e.g., keep the middle 95% of the data


#Legyen dátum szűrés a vizsgálatban? Ha igen, akkor az ezt követő dátumokra vizsgáljuk az adatokat
date_filtering = False
start_year, start_month, start_day = 2023, 3, 14
end_year, end_month, end_day = 2023, 3, 14

# sp500 = sp500.head(5)
data_folder = "News_Daily_5Y"

# %%
F_test_P_lag_sent_list = []
F_test_P_lag_ret_list = []

for i in range(1, lag+1):
    # print(i)
    F_test_P_lag_sent_list.append(f"F_test_P_lag_sent_{i}")
    F_test_P_lag_ret_list.append(f"F_test_P_ret_sent_{i}")
    
results_df = pd.DataFrame(columns=['Ticker',"Stationarity", "News_sum","News_avg","News_median", "News_negative_sum","News_negative_avg","News_negative_median", "News_positive_sum","News_positive_avg","News_positive_median", *F_test_P_lag_sent_list, *F_test_P_lag_ret_list])

# %%
irf_results = [[[[]for _ in range(length_of_irf+1)] for _ in range(number_of_charts)] for _ in range(2)]
# print(irf_results)
stationary_failed_count = 0
granger_failed_count = 0
VAR_failed_count = 0

for filename_raw in sp500:
    filename = filename_raw + ".csv"
    file_path = cwd.parent / data_folder / filename
    # file_path = cwd / data_folder / filename

    if os.path.isfile(file_path):
        data = pd.read_csv(file_path)
        short_ticker = filename_raw.split(" ")[0]
        print(f"{short_ticker} loaded successfully.")
        
        # Analyze the data and get results
        data = data_transformer(data)
        # print(data)
        
        if date_filtering:
            data['Date'] = pd.to_datetime(data['Date'])
            data = data[data['Date'] > datetime.datetime(start_year, start_month, start_day)]
            data = data[data['Date'] < datetime.datetime(end_year, end_month, end_day)]
            
            
        try:
            stationary_result = adfuller(data['Log Returns Variance'])
            stationary_result_2 = adfuller(data['Daily Sentiment Change'])
            test_failed = False
        except:
            print("The stationary test could not run.")
            stationary_failed_count += 1
            f_test_p_values_0, f_test_p_values_1 = [1] * lag, [1] * lag
            stationary_result = [0,0] 
            stationary_result_2 = [0,0] 
            test_failed = True

        # Initialize a flag to track if any of the previous tests failed

        if stationary_result[1] >= threshold:
            print(f"The '{short_ticker}' Log Returns Variance - time series is non-stationary.")
            stationary_failed_count += 1
            f_test_p_values_0, f_test_p_values_1 = [1] * lag, [1] * lag
            test_failed = True

        elif stationary_result_2[1] >= threshold:
            print(f"The '{short_ticker}' Daily Sentiment Change - time series is non-stationary.")
            stationary_failed_count += 1
            f_test_p_values_0, f_test_p_values_1 = [1] * lag, [1] * lag
            test_failed = True

        if not test_failed:
            stationarity = "Yes"
            f_test_p_values_0, chi2_test_p_values_0, granger_succes_0 = granger_test(short_ticker, data[['Log Returns Variance', 'Daily Sentiment Change']])
            f_test_p_values_1, chi2_test_p_values_1, granger_succes_1 = granger_test(short_ticker, data[['Daily Sentiment Change', 'Log Returns Variance']])
            
            if not granger_succes_0 and not granger_succes_1:
                granger_failed_count += 1
                print(f"File '{short_ticker}' Granger analysis failed.")
        else:
            stationarity = "No"
            granger_succes_0 = False
            granger_succes_1 = False
        
        
        
        state_0 = True if np.any(threshold > np.array(f_test_p_values_0)) else False
        state_1 = True if np.any(threshold > np.array(f_test_p_values_1)) else False
        
         
        # if state_0 or state_1:
        if state_0 and (granger_succes_0 or granger_succes_1):
            irf_data,irf_lower_data = irf_analysis(data, length_of_irf)
            
            if irf_data == None:
                VAR_failed_count += 1
                print(f"File '{short_ticker}' VAR analysis failed.")
            else:
                # print(irf_data)
                for id_chart, chart_list in enumerate(irf_data):
                    for id_value, value_position in enumerate(chart_list):
                        irf_results[0][id_chart][id_value].append(value_position)
                        
                for id_chart, chart_list in enumerate(irf_lower_data):
                    for id_value, value_position in enumerate(chart_list):
                        irf_results[1][id_chart][id_value].append(value_position)

        elif not state_0 and granger_succes_0 or granger_succes_1:
            print(f"File '{short_ticker}' Granger analysis resulted bellow significance.")
            
        # Create a temporary DataFrame with structured data
        temp_df = pd.DataFrame([[
            short_ticker,
            stationarity,
            data['News Publication Count (L1)'].sum(),
            data['News Publication Count (L1)'].mean().__round__(round_value),
            data['News Publication Count (L1)'].median().__round__(round_value),
            
            data["News Negative Sentiment Count"].sum(),
            data["News Negative Sentiment Count"].mean().__round__(round_value),
            data["News Negative Sentiment Count"].median().__round__(round_value),
            
            data["News Positive Sentiment Count"].sum(),
            data["News Positive Sentiment Count"].mean().__round__(round_value),
            data["News Positive Sentiment Count"].median().__round__(round_value),
            *f_test_p_values_0,  # Unpack the f_test_p_values_0 list
            *f_test_p_values_1   # Unpack the f_test_p_values_1 list
        ]], columns=results_df.columns)
        
        # Concatenate temp_df with results_df and update results_df
        results_df = pd.concat([results_df, temp_df], ignore_index=True)
    else:
        print(f"File '{filename}' does not exist in the {data_folder} folder.")
    # print("\n")

# Assuming you want to view the results_df DataFrame after the loop
print("\nFailed stationary tests:", stationary_failed_count)
print("Failed granger causality tests:", granger_failed_count)
print("Failed VAR analyis:", VAR_failed_count)
results_df
# Out:
# MSFT loaded successfully.
# File 'MSFT' Granger analysis resulted bellow significance.
# AAPL loaded successfully.
# File 'AAPL' Granger analysis resulted bellow significance.
# NVDA loaded successfully.
# File 'NVDA' Granger analysis resulted bellow significance.
# AMZN loaded successfully.
# File 'AMZN' Granger analysis resulted bellow significance.
# GOOG loaded successfully.
# File 'GOOG' Granger analysis resulted bellow significance.
# META loaded successfully.
# File 'META' Granger analysis resulted bellow significance.
# BRK_B loaded successfully.
# The 'BRK_B' Daily Sentiment Change - time series is non-stationary.
# LLY loaded successfully.
# File 'LLY' Granger analysis resulted bellow significance.
# TSLA loaded successfully.
# File 'TSLA' Granger analysis resulted bellow significance.
# AVGO loaded successfully.
# The 'AVGO' Daily Sentiment Change - time series is non-stationary.
# V loaded successfully.
# File 'V' Granger analysis resulted bellow significance.
# JPM loaded successfully.
# File 'JPM' Granger analysis resulted bellow significance.
# UNH loaded successfully.
# File 'UNH' Granger analysis resulted bellow significance.
# WMT loaded successfully.
# File 'WMT' Granger analysis resulted bellow significance.
# MA loaded successfully.
# File 'MA' Granger analysis resulted bellow significance.
# XOM loaded successfully.
# File 'XOM' Granger analysis resulted bellow significance.
# JNJ loaded successfully.
# The 'JNJ' Daily Sentiment Change - time series is non-stationary.
# PG loaded successfully.
# File 'PG' Granger analysis resulted bellow significance.
# HD loaded successfully.
# File 'HD' Granger analysis resulted bellow significance.
# MRK loaded successfully.
# File 'MRK' Granger analysis resulted bellow significance.
# COST loaded successfully.
# The 'COST' Daily Sentiment Change - time series is non-stationary.
# ABBV loaded successfully.
# File 'ABBV' Granger analysis resulted bellow significance.
# ORCL loaded successfully.
# The 'ORCL' Daily Sentiment Change - time series is non-stationary.
# CVX loaded successfully.
# The 'CVX' Daily Sentiment Change - time series is non-stationary.
# AMD loaded successfully.
# File 'AMD' Granger analysis resulted bellow significance.
# CRM loaded successfully.
# File 'CRM' Granger analysis resulted bellow significance.
# BAC loaded successfully.
# File 'BAC' Granger analysis resulted bellow significance.
# KO loaded successfully.
# File 'KO' Granger analysis resulted bellow significance.
# NFLX loaded successfully.
# File 'NFLX' Granger analysis resulted bellow significance.
# ADBE loaded successfully.
# File 'ADBE' Granger analysis resulted bellow significance.
# ACN loaded successfully.
# The 'ACN' Daily Sentiment Change - time series is non-stationary.
# PEP loaded successfully.
# File 'PEP' Granger analysis resulted bellow significance.
# MCD loaded successfully.
# File 'MCD' Granger analysis resulted bellow significance.
# TMO loaded successfully.
# The 'TMO' Daily Sentiment Change - time series is non-stationary.
# LIN loaded successfully.
# File 'LIN' Granger analysis resulted bellow significance.
# DIS loaded successfully.
# File 'DIS' Granger analysis resulted bellow significance.
# ABT loaded successfully.
# File 'ABT' Granger analysis resulted bellow significance.
# CSCO loaded successfully.
# TMUS loaded successfully.
# File 'TMUS' Granger analysis resulted bellow significance.
# WFC loaded successfully.
# File 'WFC' Granger analysis resulted bellow significance.
# DHR loaded successfully.
# The 'DHR' Daily Sentiment Change - time series is non-stationary.
# INTC loaded successfully.
# File 'INTC' Granger analysis resulted bellow significance.
# INTU loaded successfully.
# The 'INTU' Daily Sentiment Change - time series is non-stationary.
# IBM loaded successfully.
# File 'IBM' Granger analysis resulted bellow significance.
# QCOM loaded successfully.
# File 'QCOM' Granger analysis resulted bellow significance.
# VZ loaded successfully.
# AMAT loaded successfully.
# The 'AMAT' Daily Sentiment Change - time series is non-stationary.
# CMCSA loaded successfully.
# File 'CMCSA' Granger analysis resulted bellow significance.
# UBER loaded successfully.
# File 'UBER' Granger analysis resulted bellow significance.
# GE loaded successfully.
# File 'GE' Granger analysis resulted bellow significance.
# CAT loaded successfully.
# File 'CAT' Granger analysis resulted bellow significance.
# NKE loaded successfully.
# File 'NKE' Granger analysis resulted bellow significance.
# NOW loaded successfully.
# File 'NOW' Granger analysis resulted bellow significance.
# PFE loaded successfully.
# File 'PFE' Granger analysis resulted bellow significance.
# BX loaded successfully.
# File 'BX' Granger analysis resulted bellow significance.
# AXP loaded successfully.
# File 'AXP' Granger analysis resulted bellow significance.
# AMGN loaded successfully.
# File 'AMGN' Granger analysis resulted bellow significance.
# UNP loaded successfully.
# The 'UNP' Daily Sentiment Change - time series is non-stationary.
# TXN loaded successfully.
# File 'TXN' Granger analysis resulted bellow significance.
# MS loaded successfully.
# File 'MS' Granger analysis resulted bellow significance.
# PM loaded successfully.
# File 'PM' Granger analysis resulted bellow significance.
# ISRG loaded successfully.
# The 'ISRG' Daily Sentiment Change - time series is non-stationary.
# SPGI loaded successfully.
# The 'SPGI' Daily Sentiment Change - time series is non-stationary.
# SYK loaded successfully.
# The 'SYK' Daily Sentiment Change - time series is non-stationary.
# LOW loaded successfully.
# The 'LOW' Daily Sentiment Change - time series is non-stationary.
# COP loaded successfully.
# File 'COP' Granger analysis resulted bellow significance.
# GS loaded successfully.
# File 'GS' Granger analysis resulted bellow significance.
# BKNG loaded successfully.
# File 'BKNG' Granger analysis resulted bellow significance.
# HON loaded successfully.
# The 'HON' Daily Sentiment Change - time series is non-stationary.
# UPS loaded successfully.
# File 'UPS' Granger analysis resulted bellow significance.
# BA loaded successfully.
# File 'BA' Granger analysis resulted bellow significance.
# PLD loaded successfully.
# The 'PLD' Daily Sentiment Change - time series is non-stationary.
# LRCX loaded successfully.
# The 'LRCX' Daily Sentiment Change - time series is non-stationary.
# T loaded successfully.
# File 'T' Granger analysis resulted bellow significance.
# RTX loaded successfully.
# The 'RTX' Daily Sentiment Change - time series is non-stationary.
# ELV loaded successfully.
# File 'ELV' Granger analysis resulted bellow significance.
# BLK loaded successfully.
# File 'BLK' Granger analysis resulted bellow significance.
# SCHW loaded successfully.
# File 'SCHW' Granger analysis resulted bellow significance.
# PANW loaded successfully.
# File 'PANW' Granger analysis resulted bellow significance.
# NEE loaded successfully.
# The 'NEE' Daily Sentiment Change - time series is non-stationary.
# MDT loaded successfully.
# The 'MDT' Daily Sentiment Change - time series is non-stationary.
# TJX loaded successfully.
# The 'TJX' Daily Sentiment Change - time series is non-stationary.
# ETN loaded successfully.
# File 'ETN' Granger analysis resulted bellow significance.
# PGR loaded successfully.
# The 'PGR' Daily Sentiment Change - time series is non-stationary.
# VRTX loaded successfully.
# File 'VRTX' Granger analysis resulted bellow significance.
# SBUX loaded successfully.
# File 'SBUX' Granger analysis resulted bellow significance.
# C loaded successfully.
# File 'C' Granger analysis resulted bellow significance.
# REGN loaded successfully.
# File 'REGN' Granger analysis resulted bellow significance.
# ADP loaded successfully.
# File 'ADP' Granger analysis resulted bellow significance.
# LMT loaded successfully.
# CB loaded successfully.
# The 'CB' Daily Sentiment Change - time series is non-stationary.
# DE loaded successfully.
# File 'DE' Granger analysis resulted bellow significance.
# BMY loaded successfully.
# File 'BMY' Granger analysis resulted bellow significance.
# CI loaded successfully.
# The 'CI' Daily Sentiment Change - time series is non-stationary.
# ABNB loaded successfully.
# File 'ABNB' Granger analysis resulted bellow significance.
# MMC loaded successfully.
# The 'MMC' Daily Sentiment Change - time series is non-stationary.
# CVS loaded successfully.
# File 'CVS' Granger analysis resulted bellow significance.
# MDLZ loaded successfully.
# The 'MDLZ' Daily Sentiment Change - time series is non-stationary.
# BSX loaded successfully.
# The 'BSX' Daily Sentiment Change - time series is non-stationary.
# ADI loaded successfully.
# File 'ADI' Granger analysis resulted bellow significance.
# KLAC loaded successfully.
# File 'KLAC' Granger analysis resulted bellow significance.
# GILD loaded successfully.
# File 'GILD' Granger analysis resulted bellow significance.
# FI loaded successfully.
# File 'FI' Granger analysis resulted bellow significance.
# MU loaded successfully.
# File 'MU' Granger analysis resulted bellow significance.
# AMT loaded successfully.
# File 'AMT' Granger analysis resulted bellow significance.
# ZTS loaded successfully.
# File 'ZTS' Granger analysis resulted bellow significance.
# SNPS loaded successfully.
# File 'SNPS' Granger analysis resulted bellow significance.
# ANET loaded successfully.
# The 'ANET' Daily Sentiment Change - time series is non-stationary.
# HCA loaded successfully.
# File 'HCA' Granger analysis resulted bellow significance.
# EQIX loaded successfully.
# The 'EQIX' Daily Sentiment Change - time series is non-stationary.
# WM loaded successfully.
# The 'WM' Daily Sentiment Change - time series is non-stationary.
# SHW loaded successfully.
# File 'SHW' Granger analysis resulted bellow significance.
# CDNS loaded successfully.
# The 'CDNS' Daily Sentiment Change - time series is non-stationary.
# ICE loaded successfully.
# File 'ICE' Granger analysis resulted bellow significance.
# CME loaded successfully.
# File 'CME' Granger analysis resulted bellow significance.
# ITW loaded successfully.
# The 'ITW' Daily Sentiment Change - time series is non-stationary.
# GD loaded successfully.
# The 'GD' Daily Sentiment Change - time series is non-stationary.
# SO loaded successfully.
# The 'SO' Daily Sentiment Change - time series is non-stationary.
# CSX loaded successfully.
# File 'CSX' Granger analysis resulted bellow significance.
# CMG loaded successfully.
# File 'CMG' Granger analysis resulted bellow significance.
# MO loaded successfully.
# File 'MO' Granger analysis resulted bellow significance.
# DUK loaded successfully.
# The 'DUK' Daily Sentiment Change - time series is non-stationary.
# MAR loaded successfully.
# The 'MAR' Daily Sentiment Change - time series is non-stationary.
# BDX loaded successfully.
# The 'BDX' Daily Sentiment Change - time series is non-stationary.
# SLB loaded successfully.
# The 'SLB' Daily Sentiment Change - time series is non-stationary.
# TGT loaded successfully.
# File 'TGT' Granger analysis resulted bellow significance.
# CL loaded successfully.
# File 'CL' Granger analysis resulted bellow significance.
# MCO loaded successfully.
# File 'MCO' Granger analysis resulted bellow significance.
# NOC loaded successfully.
# File 'NOC' Granger analysis resulted bellow significance.
# MCK loaded successfully.
# File 'MCK' Granger analysis resulted bellow significance.
# PH loaded successfully.
# File 'PH' Granger analysis resulted bellow significance.
# EOG loaded successfully.
# The 'EOG' Daily Sentiment Change - time series is non-stationary.
# USB loaded successfully.
# File 'USB' Granger analysis resulted bellow significance.
# MPC loaded successfully.
# The 'MPC' Daily Sentiment Change - time series is non-stationary.
# TDG loaded successfully.
# File 'TDG' Granger analysis resulted bellow significance.
# PYPL loaded successfully.
# File 'PYPL' Granger analysis resulted bellow significance.
# APH loaded successfully.
# File 'APH' Granger analysis resulted bellow significance.
# PSX loaded successfully.
# File 'PSX' Granger analysis resulted bellow significance.
# CTAS loaded successfully.
# File 'CTAS' Granger analysis resulted bellow significance.
# ORLY loaded successfully.
# The 'ORLY' Daily Sentiment Change - time series is non-stationary.
# TT loaded successfully.
# File 'TT' Granger analysis resulted bellow significance.
# AON loaded successfully.
# File 'AON' Granger analysis resulted bellow significance.
# ECL loaded successfully.
# The 'ECL' Daily Sentiment Change - time series is non-stationary.
# EMR loaded successfully.
# The 'EMR' Daily Sentiment Change - time series is non-stationary.
# NXPI loaded successfully.
# File 'NXPI' Granger analysis resulted bellow significance.
# FDX loaded successfully.
# File 'FDX' Granger analysis resulted bellow significance.
# PNC loaded successfully.
# File 'PNC' Granger analysis resulted bellow significance.
# ROP loaded successfully.
# File 'ROP' Granger analysis resulted bellow significance.
# MNST loaded successfully.
# File 'MNST' Granger analysis resulted bellow significance.
# NSC loaded successfully.
# The 'NSC' Daily Sentiment Change - time series is non-stationary.
# RSG loaded successfully.
# The 'RSG' Daily Sentiment Change - time series is non-stationary.
# LULU loaded successfully.
# File 'LULU' Granger analysis resulted bellow significance.
# PCAR loaded successfully.
# File 'PCAR' Granger analysis resulted bellow significance.
# FCX loaded successfully.
# File 'FCX' Granger analysis resulted bellow significance.
# ADSK loaded successfully.
# The 'ADSK' Daily Sentiment Change - time series is non-stationary.
# PXD loaded successfully.
# The 'PXD' Daily Sentiment Change - time series is non-stationary.
# MSI loaded successfully.
# File 'MSI' Granger analysis resulted bellow significance.
# OXY loaded successfully.
# The 'OXY' Daily Sentiment Change - time series is non-stationary.
# WELL loaded successfully.
# File 'WELL' Granger analysis resulted bellow significance.
# FTNT loaded successfully.
# The 'FTNT' Daily Sentiment Change - time series is non-stationary.
# EL loaded successfully.
# File 'EL' Granger analysis resulted bellow significance.
# COF loaded successfully.
# File 'COF' Granger analysis resulted bellow significance.
# AJG loaded successfully.
# File 'AJG' Granger analysis resulted bellow significance.
# EW loaded successfully.
# The 'EW' Daily Sentiment Change - time series is non-stationary.
# MMM loaded successfully.
# File 'MMM' Granger analysis resulted bellow significance.
# APD loaded successfully.
# The 'APD' Daily Sentiment Change - time series is non-stationary.
# TRV loaded successfully.
# File 'TRV' Granger analysis resulted bellow significance.
# HLT loaded successfully.
# The 'HLT' Daily Sentiment Change - time series is non-stationary.
# CHTR loaded successfully.
# File 'CHTR' Granger analysis resulted bellow significance.
# MET loaded successfully.
# File 'MET' Granger analysis resulted bellow significance.
# PSA loaded successfully.
# The 'PSA' Daily Sentiment Change - time series is non-stationary.
# F loaded successfully.
# File 'F' Granger analysis resulted bellow significance.
# SPG loaded successfully.
# File 'SPG' Granger analysis resulted bellow significance.
# CARR loaded successfully.
# ROST loaded successfully.
# The 'ROST' Daily Sentiment Change - time series is non-stationary.
# TFC loaded successfully.
# File 'TFC' Granger analysis resulted bellow significance.
# AIG loaded successfully.
# File 'AIG' Granger analysis resulted bellow significance.
# VLO loaded successfully.
# File 'VLO' Granger analysis resulted bellow significance.
# AZO loaded successfully.
# The 'AZO' Daily Sentiment Change - time series is non-stationary.
# CPRT loaded successfully.
# The 'CPRT' Daily Sentiment Change - time series is non-stationary.
# CCI loaded successfully.
# The 'CCI' Daily Sentiment Change - time series is non-stationary.
# DHI loaded successfully.
# The 'DHI' Daily Sentiment Change - time series is non-stationary.
# GWW loaded successfully.
# File 'GWW' Granger analysis resulted bellow significance.
# COR loaded successfully.
# File 'COR' Granger analysis resulted bellow significance.
# ODFL loaded successfully.
# The 'ODFL' Daily Sentiment Change - time series is non-stationary.
# IDXX loaded successfully.
# The 'IDXX' Daily Sentiment Change - time series is non-stationary.
# AFL loaded successfully.
# File 'AFL' Granger analysis resulted bellow significance.
# NUE loaded successfully.
# HES loaded successfully.
# File 'HES' Granger analysis resulted bellow significance.
# DXCM loaded successfully.
# File 'DXCM' Granger analysis resulted bellow significance.
# MSCI loaded successfully.
# File 'MSCI' Granger analysis resulted bellow significance.
# GM loaded successfully.
# File 'GM' Granger analysis resulted bellow significance.
# STZ loaded successfully.
# File 'STZ' Granger analysis resulted bellow significance.
# PAYX loaded successfully.
# File 'PAYX' Granger analysis resulted bellow significance.
# SRE loaded successfully.
# File 'SRE' Granger analysis resulted bellow significance.
# HUM loaded successfully.
# MCHP loaded successfully.
# File 'MCHP' Granger analysis resulted bellow significance.
# TEL loaded successfully.
# File 'TEL' Granger analysis resulted bellow significance.
# URI loaded successfully.
# File 'URI' Granger analysis resulted bellow significance.
# O loaded successfully.
# The 'O' Daily Sentiment Change - time series is non-stationary.
# DLR loaded successfully.
# The 'DLR' Daily Sentiment Change - time series is non-stationary.
# KDP loaded successfully.
# File 'KDP' Granger analysis resulted bellow significance.
# IQV loaded successfully.
# The 'IQV' Daily Sentiment Change - time series is non-stationary.
# ALL loaded successfully.
# File 'ALL' Granger analysis resulted bellow significance.
# KHC loaded successfully.
# The 'KHC' Daily Sentiment Change - time series is non-stationary.
# CNC loaded successfully.
# File 'CNC' Granger analysis resulted bellow significance.
# OKE loaded successfully.
# The 'OKE' Daily Sentiment Change - time series is non-stationary.
# AEP loaded successfully.
# The 'AEP' Daily Sentiment Change - time series is non-stationary.
# CEG loaded successfully.
# BK loaded successfully.
# File 'BK' Granger analysis resulted bellow significance.
# LEN loaded successfully.
# The 'LEN' Daily Sentiment Change - time series is non-stationary.
# WMB loaded successfully.
# File 'WMB' Granger analysis resulted bellow significance.
# LVS loaded successfully.
# The 'LVS' Daily Sentiment Change - time series is non-stationary.
# AMP loaded successfully.
# File 'AMP' Granger analysis resulted bellow significance.
# FAST loaded successfully.
# The 'FAST' Daily Sentiment Change - time series is non-stationary.
# LHX loaded successfully.
# File 'LHX' Granger analysis resulted bellow significance.
# AME loaded successfully.
# The 'AME' Daily Sentiment Change - time series is non-stationary.
# KMB loaded successfully.
# File 'KMB' Granger analysis resulted bellow significance.
# SYY loaded successfully.
# File 'SYY' Granger analysis resulted bellow significance.
# A loaded successfully.
# File 'A' Granger analysis resulted bellow significance.
# GEHC loaded successfully.
# File 'GEHC' Granger analysis resulted bellow significance.
# HSY loaded successfully.
# File 'HSY' Granger analysis resulted bellow significance.
# DOW loaded successfully.
# File 'DOW' Granger analysis resulted bellow significance.
# JCI loaded successfully.
# File 'JCI' Granger analysis resulted bellow significance.
# PRU loaded successfully.
# File 'PRU' Granger analysis resulted bellow significance.
# CTVA loaded successfully.
# File 'CTVA' Granger analysis resulted bellow significance.
# NEM loaded successfully.
# The 'NEM' Daily Sentiment Change - time series is non-stationary.
# D loaded successfully.
# The 'D' Daily Sentiment Change - time series is non-stationary.
# CTSH loaded successfully.
# File 'CTSH' Granger analysis resulted bellow significance.
# EA loaded successfully.
# File 'EA' Granger analysis resulted bellow significance.
# KMI loaded successfully.
# File 'KMI' Granger analysis resulted bellow significance.
# YUM loaded successfully.
# File 'YUM' Granger analysis resulted bellow significance.
# CMI loaded successfully.
# File 'CMI' Granger analysis resulted bellow significance.
# FIS loaded successfully.
# The 'FIS' Daily Sentiment Change - time series is non-stationary.
# OTIS loaded successfully.
# File 'OTIS' Granger analysis resulted bellow significance.
# KVUE loaded successfully.
# File 'KVUE' Granger analysis resulted bellow significance.
# GIS loaded successfully.
# File 'GIS' Granger analysis resulted bellow significance.
# IR loaded successfully.
# File 'IR' Granger analysis resulted bellow significance.
# VRSK loaded successfully.
# File 'VRSK' Granger analysis resulted bellow significance.
# MPWR loaded successfully.
# File 'MPWR' Granger analysis resulted bellow significance.
# PCG loaded successfully.
# File 'PCG' Granger analysis resulted bellow significance.
# IT loaded successfully.
# File 'IT' Granger analysis resulted bellow significance.
# EXC loaded successfully.
# The 'EXC' Daily Sentiment Change - time series is non-stationary.
# GPN loaded successfully.
# File 'GPN' Granger analysis resulted bellow significance.
# KR loaded successfully.
# File 'KR' Granger analysis resulted bellow significance.
# VMC loaded successfully.
# File 'VMC' Granger analysis resulted bellow significance.
# MRNA loaded successfully.
# File 'MRNA' Granger analysis resulted bellow significance.
# ON loaded successfully.
# File 'ON' Granger analysis resulted bellow significance.
# PPG loaded successfully.
# The 'PPG' Daily Sentiment Change - time series is non-stationary.
# MLM loaded successfully.
# File 'MLM' Granger analysis resulted bellow significance.
# CSGP loaded successfully.
# File 'CSGP' Granger analysis resulted bellow significance.
# XEL loaded successfully.
# The 'XEL' Daily Sentiment Change - time series is non-stationary.
# CDW loaded successfully.
# File 'CDW' Granger analysis resulted bellow significance.
# ACGL loaded successfully.
# The 'ACGL' Daily Sentiment Change - time series is non-stationary.
# ROK loaded successfully.
# File 'ROK' Granger analysis resulted bellow significance.
# NDAQ loaded successfully.
# File 'NDAQ' Granger analysis resulted bellow significance.
# FANG loaded successfully.
# The 'FANG' Daily Sentiment Change - time series is non-stationary.
# FICO loaded successfully.
# The 'FICO' Daily Sentiment Change - time series is non-stationary.
# BIIB loaded successfully.
# File 'BIIB' Granger analysis resulted bellow significance.
# EFX loaded successfully.
# File 'EFX' Granger analysis resulted bellow significance.
# LYB loaded successfully.
# File 'LYB' Granger analysis resulted bellow significance.
# HAL loaded successfully.
# The 'HAL' Daily Sentiment Change - time series is non-stationary.
# DLTR loaded successfully.
# File 'DLTR' Granger analysis resulted bellow significance.
# DG loaded successfully.
# File 'DG' Granger analysis resulted bellow significance.
# PWR loaded successfully.
# File 'PWR' Granger analysis resulted bellow significance.
# VICI loaded successfully.
# File 'VICI' Granger analysis resulted bellow significance.
# ED loaded successfully.
# The 'ED' Daily Sentiment Change - time series is non-stationary.
# EXR loaded successfully.
# The 'EXR' Daily Sentiment Change - time series is non-stationary.
# XYL loaded successfully.
# The 'XYL' Daily Sentiment Change - time series is non-stationary.
# PEG loaded successfully.
# The 'PEG' Daily Sentiment Change - time series is non-stationary.
# RCL loaded successfully.
# File 'RCL' Granger analysis resulted bellow significance.
# FTV loaded successfully.
# File 'FTV' Granger analysis resulted bellow significance.
# BKR loaded successfully.
# File 'BKR' Granger analysis resulted bellow significance.
# ANSS loaded successfully.
# File 'ANSS' Granger analysis resulted bellow significance.
# WTW loaded successfully.
# File 'WTW' Granger analysis resulted bellow significance.
# ADM loaded successfully.
# File 'ADM' Granger analysis resulted bellow significance.
# DD loaded successfully.
# CBRE loaded successfully.
# File 'CBRE' Granger analysis resulted bellow significance.
# HPQ loaded successfully.
# File 'HPQ' Granger analysis resulted bellow significance.
# DVN loaded successfully.
# The 'DVN' Daily Sentiment Change - time series is non-stationary.
# HIG loaded successfully.
# The 'HIG' Daily Sentiment Change - time series is non-stationary.
# BF_B loaded successfully.
# File 'BF_B' Granger analysis resulted bellow significance.
# DFS loaded successfully.
# File 'DFS' Granger analysis resulted bellow significance.
# GLW loaded successfully.
# File 'GLW' Granger analysis resulted bellow significance.
# KEYS loaded successfully.
# File 'KEYS' Granger analysis resulted bellow significance.
# WST loaded successfully.
# File 'WST' Granger analysis resulted bellow significance.
# RMD loaded successfully.
# File 'RMD' Granger analysis resulted bellow significance.
# TTWO loaded successfully.
# File 'TTWO' Granger analysis resulted bellow significance.
# ZBH loaded successfully.
# The 'ZBH' Daily Sentiment Change - time series is non-stationary.
# ULTA loaded successfully.
# File 'ULTA' Granger analysis resulted bellow significance.
# DAL loaded successfully.
# File 'DAL' Granger analysis resulted bellow significance.
# HWM loaded successfully.
# File 'HWM' Granger analysis resulted bellow significance.
# TSCO loaded successfully.
# File 'TSCO' Granger analysis resulted bellow significance.
# MTD loaded successfully.
# The 'MTD' Daily Sentiment Change - time series is non-stationary.
# EIX loaded successfully.
# File 'EIX' Granger analysis resulted bellow significance.
# CAH loaded successfully.
# File 'CAH' Granger analysis resulted bellow significance.
# AVB loaded successfully.
# File 'AVB' Granger analysis resulted bellow significance.
# RJF loaded successfully.
# File 'RJF' Granger analysis resulted bellow significance.
# WEC loaded successfully.
# The 'WEC' Daily Sentiment Change - time series is non-stationary.
# TROW loaded successfully.
# File 'TROW' Granger analysis resulted bellow significance.
# WY loaded successfully.
# The 'WY' Daily Sentiment Change - time series is non-stationary.
# WBD loaded successfully.
# File 'WBD' Granger analysis resulted bellow significance.
# AWK loaded successfully.
# File 'AWK' Granger analysis resulted bellow significance.
# CHD loaded successfully.
# File 'CHD' Granger analysis resulted bellow significance.
# WAB loaded successfully.
# File 'WAB' Granger analysis resulted bellow significance.
# ALGN loaded successfully.
# The 'ALGN' Daily Sentiment Change - time series is non-stationary.
# NVR loaded successfully.
# File 'NVR' Granger analysis resulted bellow significance.
# BRO loaded successfully.
# The 'BRO' Daily Sentiment Change - time series is non-stationary.
# MOH loaded successfully.
# GRMN loaded successfully.
# File 'GRMN' Granger analysis resulted bellow significance.
# BR loaded successfully.
# The 'BR' Daily Sentiment Change - time series is non-stationary.
# FITB loaded successfully.
# File 'FITB' Granger analysis resulted bellow significance.
# MTB loaded successfully.
# File 'MTB' Granger analysis resulted bellow significance.
# STE loaded successfully.
# File 'STE' Granger analysis resulted bellow significance.
# ILMN loaded successfully.
# File 'ILMN' Granger analysis resulted bellow significance.
# EQR loaded successfully.
# The 'EQR' Daily Sentiment Change - time series is non-stationary.
# BLDR loaded successfully.
# File 'BLDR' Granger analysis resulted bellow significance.
# DOV loaded successfully.
# The 'DOV' Daily Sentiment Change - time series is non-stationary.
# EBAY loaded successfully.
# File 'EBAY' Granger analysis resulted bellow significance.
# SBAC loaded successfully.
# The 'SBAC' Daily Sentiment Change - time series is non-stationary.
# DTE loaded successfully.
# The 'DTE' Daily Sentiment Change - time series is non-stationary.
# APTV loaded successfully.
# The 'APTV' Daily Sentiment Change - time series is non-stationary.
# STT loaded successfully.
# File 'STT' Granger analysis resulted bellow significance.
# JBHT loaded successfully.
# File 'JBHT' Granger analysis resulted bellow significance.
# TRGP loaded successfully.
# File 'TRGP' Granger analysis resulted bellow significance.
# PHM loaded successfully.
# File 'PHM' Granger analysis resulted bellow significance.
# FE loaded successfully.
# File 'FE' Granger analysis resulted bellow significance.
# LYV loaded successfully.
# File 'LYV' Granger analysis resulted bellow significance.
# PTC loaded successfully.
# File 'PTC' VAR analysis failed.
# VLTO loaded successfully.
# The 'VLTO' Log Returns Variance - time series is non-stationary.
# WRB loaded successfully.
# File 'WRB' Granger analysis resulted bellow significance.
# ETR loaded successfully.
# File 'ETR' Granger analysis resulted bellow significance.
# BAX loaded successfully.
# ARE loaded successfully.
# File 'ARE' Granger analysis resulted bellow significance.
# IFF loaded successfully.
# File 'IFF' Granger analysis resulted bellow significance.
# ES loaded successfully.
# File 'ES' Granger analysis resulted bellow significance.
# TDY loaded successfully.
# File 'TDY' Granger analysis resulted bellow significance.
# LUV loaded successfully.
# The 'LUV' Daily Sentiment Change - time series is non-stationary.
# AXON loaded successfully.
# File 'AXON' Granger analysis resulted bellow significance.
# INVH loaded successfully.
# File 'INVH' Granger analysis resulted bellow significance.
# STLD loaded successfully.
# File 'STLD' Granger analysis resulted bellow significance.
# GPC loaded successfully.
# File 'GPC' Granger analysis resulted bellow significance.
# ROL loaded successfully.
# File 'ROL' Granger analysis resulted bellow significance.
# IRM loaded successfully.
# File 'IRM' Granger analysis resulted bellow significance.
# CBOE loaded successfully.
# File 'CBOE' Granger analysis resulted bellow significance.
# PPL loaded successfully.
# File 'PPL' Granger analysis resulted bellow significance.
# FLT loaded successfully.
# File 'FLT' Granger analysis resulted bellow significance.
# VRSN loaded successfully.
# File 'VRSN' Granger analysis resulted bellow significance.
# BALL loaded successfully.
# File 'BALL' Granger analysis resulted bellow significance.
# HPE loaded successfully.
# File 'HPE' Granger analysis resulted bellow significance.
# DRI loaded successfully.
# File 'DRI' Granger analysis resulted bellow significance.
# HUBB loaded successfully.
# File 'HUBB' Granger analysis resulted bellow significance.
# WAT loaded successfully.
# File 'WAT' Granger analysis resulted bellow significance.
# PFG loaded successfully.
# The 'PFG' Daily Sentiment Change - time series is non-stationary.
# K loaded successfully.
# File 'K' Granger analysis resulted bellow significance.
# WBA loaded successfully.
# File 'WBA' Granger analysis resulted bellow significance.
# TSN loaded successfully.
# File 'TSN' Granger analysis resulted bellow significance.
# CLX loaded successfully.
# File 'CLX' Granger analysis resulted bellow significance.
# HBAN loaded successfully.
# File 'HBAN' Granger analysis resulted bellow significance.
# TYL loaded successfully.
# File 'TYL' Granger analysis resulted bellow significance.
# CTRA loaded successfully.
# File 'CTRA' Granger analysis resulted bellow significance.
# CCL loaded successfully.
# The 'CCL' Daily Sentiment Change - time series is non-stationary.
# J loaded successfully.
# File 'J' Granger analysis resulted bellow significance.
# COO loaded successfully.
# File 'COO' Granger analysis resulted bellow significance.
# EXPE loaded successfully.
# File 'EXPE' Granger analysis resulted bellow significance.
# LH loaded successfully.
# File 'LH' Granger analysis resulted bellow significance.
# STX loaded successfully.
# File 'STX' Granger analysis resulted bellow significance.
# AEE loaded successfully.
# File 'AEE' Granger analysis resulted bellow significance.
# EXPD loaded successfully.
# The 'EXPD' Daily Sentiment Change - time series is non-stationary.
# EPAM loaded successfully.
# File 'EPAM' Granger analysis resulted bellow significance.
# ENPH loaded successfully.
# File 'ENPH' Granger analysis resulted bellow significance.
# MKC loaded successfully.
# File 'MKC' Granger analysis resulted bellow significance.
# JBL loaded successfully.
# File 'JBL' Granger analysis resulted bellow significance.
# NTAP loaded successfully.
# The 'NTAP' Daily Sentiment Change - time series is non-stationary.
# VTR loaded successfully.
# File 'VTR' Granger analysis resulted bellow significance.
# WDC loaded successfully.
# File 'WDC' Granger analysis resulted bellow significance.
# CINF loaded successfully.
# File 'CINF' Granger analysis resulted bellow significance.
# CNP loaded successfully.
# The 'CNP' Daily Sentiment Change - time series is non-stationary.
# FDS loaded successfully.
# File 'FDS' Granger analysis resulted bellow significance.
# OMC loaded successfully.
# File 'OMC' Granger analysis resulted bellow significance.
# HOLX loaded successfully.
# File 'HOLX' Granger analysis resulted bellow significance.
# IEX loaded successfully.
# File 'IEX' Granger analysis resulted bellow significance.
# ATO loaded successfully.
# The 'ATO' Daily Sentiment Change - time series is non-stationary.
# RF loaded successfully.
# File 'RF' Granger analysis resulted bellow significance.
# AVY loaded successfully.
# File 'AVY' Granger analysis resulted bellow significance.
# LDOS loaded successfully.
# File 'LDOS' Granger analysis resulted bellow significance.
# FSLR loaded successfully.
# File 'FSLR' Granger analysis resulted bellow significance.
# CMS loaded successfully.
# File 'CMS' Granger analysis resulted bellow significance.
# SWKS loaded successfully.
# File 'SWKS' Granger analysis resulted bellow significance.
# TXT loaded successfully.
# File 'TXT' Granger analysis resulted bellow significance.
# L loaded successfully.
# File 'L' Granger analysis resulted bellow significance.
# AKAM loaded successfully.
# The 'AKAM' Daily Sentiment Change - time series is non-stationary.
# CE loaded successfully.
# File 'CE' Granger analysis resulted bellow significance.
# NTRS loaded successfully.
# File 'NTRS' Granger analysis resulted bellow significance.
# SYF loaded successfully.
# File 'SYF' Granger analysis resulted bellow significance.
# MAS loaded successfully.
# File 'MAS' Granger analysis resulted bellow significance.
# EG loaded successfully.
# File 'EG' Granger analysis resulted bellow significance.
# BBY loaded successfully.
# File 'BBY' Granger analysis resulted bellow significance.
# HRL loaded successfully.
# File 'HRL' Granger analysis resulted bellow significance.
# VTRS loaded successfully.
# File 'VTRS' Granger analysis resulted bellow significance.
# TER loaded successfully.
# File 'TER' Granger analysis resulted bellow significance.
# EQT loaded successfully.
# File 'EQT' Granger analysis resulted bellow significance.
# NWS loaded successfully.
# File 'NWS' Granger analysis resulted bellow significance.
# ESS loaded successfully.
# File 'ESS' Granger analysis resulted bellow significance.
# MAA loaded successfully.
# File 'MAA' Granger analysis resulted bellow significance.
# NDSN loaded successfully.
# The 'NDSN' Daily Sentiment Change - time series is non-stationary.
# PKG loaded successfully.
# File 'PKG' Granger analysis resulted bellow significance.
# TRMB loaded successfully.
# File 'TRMB' Granger analysis resulted bellow significance.
# POOL loaded successfully.
# File 'POOL' Granger analysis resulted bellow significance.
# CF loaded successfully.
# File 'CF' Granger analysis resulted bellow significance.
# BG loaded successfully.
# File 'BG' Granger analysis resulted bellow significance.
# DPZ loaded successfully.
# LW loaded successfully.
# File 'LW' Granger analysis resulted bellow significance.
# CFG loaded successfully.
# File 'CFG' Granger analysis resulted bellow significance.
# ALB loaded successfully.
# File 'ALB' Granger analysis resulted bellow significance.
# BEN loaded successfully.
# File 'BEN' Granger analysis resulted bellow significance.
# ZBRA loaded successfully.
# File 'ZBRA' Granger analysis resulted bellow significance.
# SNA loaded successfully.
# File 'SNA' Granger analysis resulted bellow significance.
# HST loaded successfully.
# File 'HST' Granger analysis resulted bellow significance.
# MGM loaded successfully.
# File 'MGM' Granger analysis resulted bellow significance.
# FOX loaded successfully.
# File 'FOX' Granger analysis resulted bellow significance.
# UAL loaded successfully.
# File 'UAL' Granger analysis resulted bellow significance.
# DGX loaded successfully.
# File 'DGX' Granger analysis resulted bellow significance.
# MRO loaded successfully.
# File 'MRO' Granger analysis resulted bellow significance.
# GEN loaded successfully.
# The 'GEN' Daily Sentiment Change - time series is non-stationary.
# SWK loaded successfully.
# File 'SWK' Granger analysis resulted bellow significance.
# LKQ loaded successfully.
# File 'LKQ' Granger analysis resulted bellow significance.
# PODD loaded successfully.
# File 'PODD' Granger analysis resulted bellow significance.
# TAP loaded successfully.
# File 'TAP' Granger analysis resulted bellow significance.
# KIM loaded successfully.
# The 'KIM' Daily Sentiment Change - time series is non-stationary.
# KEY loaded successfully.
# File 'KEY' Granger analysis resulted bellow significance.
# SJM loaded successfully.
# AMCR loaded successfully.
# File 'AMCR' Granger analysis resulted bellow significance.
# INCY loaded successfully.
# File 'INCY' Granger analysis resulted bellow significance.
# CAG loaded successfully.
# The 'CAG' Daily Sentiment Change - time series is non-stationary.
# RVTY loaded successfully.
# File 'RVTY' Granger analysis resulted bellow significance.
# CRL loaded successfully.
# File 'CRL' Granger analysis resulted bellow significance.
# JKHY loaded successfully.
# File 'JKHY' Granger analysis resulted bellow significance.
# IPG loaded successfully.
# File 'IPG' Granger analysis resulted bellow significance.
# IP loaded successfully.
# The 'IP' Daily Sentiment Change - time series is non-stationary.
# PNR loaded successfully.
# File 'PNR' Granger analysis resulted bellow significance.
# CPB loaded successfully.
# File 'CPB' Granger analysis resulted bellow significance.
# LNT loaded successfully.
# The 'LNT' Daily Sentiment Change - time series is non-stationary.
# JNPR loaded successfully.
# WYNN loaded successfully.
# File 'WYNN' Granger analysis resulted bellow significance.
# UDR loaded successfully.
# The 'UDR' Daily Sentiment Change - time series is non-stationary.
# GL loaded successfully.
# File 'GL' Granger analysis resulted bellow significance.
# TFX loaded successfully.
# The 'TFX' Daily Sentiment Change - time series is non-stationary.
# AOS loaded successfully.
# File 'AOS' Granger analysis resulted bellow significance.
# NRG loaded successfully.
# The 'NRG' Daily Sentiment Change - time series is non-stationary.
# ALLE loaded successfully.
# File 'ALLE' Granger analysis resulted bellow significance.
# REG loaded successfully.
# The 'REG' Daily Sentiment Change - time series is non-stationary.
# RL loaded successfully.
# File 'RL' Granger analysis resulted bellow significance.
# EVRG loaded successfully.
# File 'EVRG' Granger analysis resulted bellow significance.
# DAY loaded successfully.
# The 'DAY' Daily Sentiment Change - time series is non-stationary.
# KMX loaded successfully.
# File 'KMX' Granger analysis resulted bellow significance.
# HII loaded successfully.
# File 'HII' Granger analysis resulted bellow significance.
# TECH loaded successfully.
# WRK loaded successfully.
# File 'WRK' Granger analysis resulted bellow significance.
# AES loaded successfully.
# File 'AES' Granger analysis resulted bellow significance.
# UHS loaded successfully.
# File 'UHS' Granger analysis resulted bellow significance.
# PAYC loaded successfully.
# File 'PAYC' Granger analysis resulted bellow significance.
# QRVO loaded successfully.
# File 'QRVO' Granger analysis resulted bellow significance.
# FFIV loaded successfully.
# File 'FFIV' Granger analysis resulted bellow significance.
# DVA loaded successfully.
# NI loaded successfully.
# The 'NI' Daily Sentiment Change - time series is non-stationary.
# BXP loaded successfully.
# File 'BXP' Granger analysis resulted bellow significance.
# TPR loaded successfully.
# File 'TPR' Granger analysis resulted bellow significance.
# CTLT loaded successfully.
# File 'CTLT' Granger analysis resulted bellow significance.
# CPT loaded successfully.
# File 'CPT' Granger analysis resulted bellow significance.
# BBWI loaded successfully.
# File 'BBWI' Granger analysis resulted bellow significance.
# MTCH loaded successfully.
# File 'MTCH' Granger analysis resulted bellow significance.
# EMN loaded successfully.
# File 'EMN' Granger analysis resulted bellow significance.
# MOS loaded successfully.
# File 'MOS' Granger analysis resulted bellow significance.
# HSIC loaded successfully.
# File 'HSIC' Granger analysis resulted bellow significance.
# BIO loaded successfully.
# File 'BIO' Granger analysis resulted bellow significance.
# APA loaded successfully.
# File 'APA' Granger analysis resulted bellow significance.
# AAL loaded successfully.
# The 'AAL' Daily Sentiment Change - time series is non-stationary.
# PEAK loaded successfully.
# The stationary test could not run.
# CZR loaded successfully.
# File 'CZR' Granger analysis resulted bellow significance.
# ETSY loaded successfully.
# File 'ETSY' Granger analysis resulted bellow significance.
# AIZ loaded successfully.
# File 'AIZ' Granger analysis resulted bellow significance.
# RHI loaded successfully.
# File 'RHI' Granger analysis resulted bellow significance.
# CHRW loaded successfully.
# The 'CHRW' Daily Sentiment Change - time series is non-stationary.
# FRT loaded successfully.
# The 'FRT' Daily Sentiment Change - time series is non-stationary.
# MKTX loaded successfully.
# PARA loaded successfully.
# File 'PARA' Granger analysis resulted bellow significance.
# PNW loaded successfully.
# File 'PNW' Granger analysis resulted bellow significance.
# MHK loaded successfully.
# File 'MHK' Granger analysis resulted bellow significance.
# XRAY loaded successfully.
# File 'XRAY' Granger analysis resulted bellow significance.
# GNRC loaded successfully.
# File 'GNRC' Granger analysis resulted bellow significance.
# HAS loaded successfully.
# File 'HAS' Granger analysis resulted bellow significance.
# BWA loaded successfully.
# File 'BWA' Granger analysis resulted bellow significance.
# IVZ loaded successfully.
# File 'IVZ' Granger analysis resulted bellow significance.
# NCLH loaded successfully.
# File 'NCLH' Granger analysis resulted bellow significance.
# CMA loaded successfully.
# File 'CMA' Granger analysis resulted bellow significance.
# FMC loaded successfully.
# File 'FMC' Granger analysis resulted bellow significance.
# VFC loaded successfully.
# The 'VFC' Daily Sentiment Change - time series is non-stationary.
# ZION loaded successfully.
# File 'ZION' Granger analysis resulted bellow significance.
# WHR loaded successfully.
# File 'WHR' Granger analysis resulted bellow significance.
#
# Failed stationary tests: 126
# Failed granger causality tests: 0
# Failed VAR analyis: 1
#     Ticker Stationarity   News_sum     News_avg  News_median  \
# 0     MSFT          Yes  1693054.0  1349.047012       1309.0
# 1     AAPL          Yes  2701223.0  2152.368924       2090.0
# 2     NVDA          Yes   486168.0   387.384861        293.0
# 3     AMZN          Yes   766863.0   611.046215        514.0
# 4     GOOG          Yes  1277159.0  1017.656574        919.0
# ..     ...          ...        ...          ...          ...
# 495    CMA          Yes    44949.0    37.086634         28.0
# 496    FMC          Yes    28664.0    25.800180         18.0
# 497    VFC           No    42506.0    34.840984         25.0
# 498   ZION          Yes    27574.0    26.718992         20.0
# 499    WHR          Yes    50313.0    40.542305         30.0
#
#      News_negative_sum  News_negative_avg  News_negative_median  \
# 0             -13007.0         -10.364143                  -4.0
# 1             -34866.0         -27.781673                 -17.0
# 2              -7760.0          -6.183267                  -2.0
# 3             -17424.0         -13.883665                  -8.0
# 4             -41667.0         -33.200797                 -17.0
# ..                 ...                ...                   ...
# 495            -1213.0          -1.000825                   0.0
# 496            -1111.0          -1.000000                   0.0
# 497            -1788.0          -1.465574                   0.0
# 498             -535.0          -0.518411                   0.0
# 499             -888.0          -0.715552                   0.0
#
#      News_positive_sum  News_positive_avg  News_positive_median  \
# 0              15800.0          12.589641                   5.0
# 1              21973.0          17.508367                   9.0
# 2              15624.0          12.449402                   4.0
# 3              12661.0          10.088446                   5.0
# 4               9351.0           7.450996                   3.0
# ..                 ...                ...                   ...
# 495              822.0           0.678218                   0.0
# 496              704.0           0.633663                   0.0
# 497             1384.0           1.134426                   0.0
# 498              444.0           0.430233                   0.0
# 499              916.0           0.738114                   0.0
#
#      F_test_P_lag_sent_1  F_test_P_lag_sent_2  F_test_P_lag_sent_3  \
# 0                0.03037              0.07519              0.09277
# 1                0.08120              0.13712              0.24955
# 2                0.04115              0.01364              0.02922
# 3                0.06813              0.05130              0.08448
# 4                0.08560              0.01888              0.02455
# ..                   ...                  ...                  ...
# 495              0.62777              0.77499              0.76776
# 496              0.20869              0.46414              0.72652
# 497              1.00000              1.00000              1.00000
# 498              0.47582              0.59491              0.69923
# 499              0.20888              0.30932              0.51528
#
#      F_test_P_lag_sent_4  F_test_P_lag_sent_5  F_test_P_lag_sent_6  \
# 0                0.15826              0.26796              0.39357
# 1                0.46537              0.17795              0.25925
# 2                0.01693              0.05219              0.03227
# 3                0.07194              0.11653              0.15099
# 4                0.04630              0.03367              0.04494
# ..                   ...                  ...                  ...
# 495              0.81943              0.76943              0.78830
# 496              0.87532              0.88085              0.93851
# 497              1.00000              1.00000              1.00000
# 498              0.80683              0.88985              0.88257
# 499              0.67683              0.81066              0.91703
#
#      F_test_P_lag_sent_7  F_test_P_lag_sent_8  F_test_P_lag_sent_9  \
# 0                0.50214              0.61827              0.74655
# 1                0.24169              0.49573              0.66992
# 2                0.05140              0.05313              0.08394
# 3                0.21699              0.28566              0.22070
# 4                0.04398              0.06412              0.09905
# ..                   ...                  ...                  ...
# 495              0.72340              0.80731              0.81120
# 496              0.94331              0.97032              0.87000
# 497              1.00000              1.00000              1.00000
# 498              0.91108              0.92564              0.87610
# 499              0.95115              0.94744              0.97209
#
#      F_test_P_lag_sent_10  F_test_P_ret_sent_1  F_test_P_ret_sent_2  \
# 0                 0.75489              0.48463              0.00800
# 1                 0.76730              0.60263              0.29743
# 2                 0.11860              0.00000              0.00000
# 3                 0.21540              0.62683              0.63275
# 4                 0.14357              0.15806              0.07812
# ..                    ...                  ...                  ...
# 495               0.87388              0.34002              0.10176
# 496               0.89802              0.77482              0.55811
# 497               1.00000              1.00000              1.00000
# 498               0.92278              0.06834              0.06859
# 499               0.96618              0.75690              0.54139
#
#      F_test_P_ret_sent_3  F_test_P_ret_sent_4  F_test_P_ret_sent_5  \
# 0                0.02644              0.04502              0.03554
# 1                0.06829              0.08055              0.12362
# 2                0.00000              0.00000              0.00000
# 3                0.21643              0.27509              0.11590
# 4                0.21687              0.33165              0.42323
# ..                   ...                  ...                  ...
# 495              0.17170              0.24323              0.13168
# 496              0.73042              0.84167              0.94010
# 497              1.00000              1.00000              1.00000
# 498              0.13702              0.16855              0.22000
# 499              0.77676              0.92517              0.93917
#
#      F_test_P_ret_sent_6  F_test_P_ret_sent_7  F_test_P_ret_sent_8  \
# 0                0.06848              0.10939              0.12072
# 1                0.15109              0.23759              0.33156
# 2                0.00000              0.00000              0.00000
# 3                0.10281              0.15368              0.08524
# 4                0.52066              0.53527              0.54082
# ..                   ...                  ...                  ...
# 495              0.14697              0.15790              0.05099
# 496              0.94706              0.94674              0.97574
# 497              1.00000              1.00000              1.00000
# 498              0.31951              0.31013              0.32881
# 499              0.96919              0.96189              0.98016
#
#      F_test_P_ret_sent_9  F_test_P_ret_sent_10
# 0                0.18137               0.22983
# 1                0.44925               0.54303
# 2                0.00000               0.00000
# 3                0.13264               0.20050
# 4                0.67301               0.76546
# ..                   ...                   ...
# 495              0.07364               0.10099
# 496              0.99023               0.98847
# 497              1.00000               1.00000
# 498              0.26829               0.02245
# 499              0.98962               0.99498
#
# [500 rows x 31 columns]

# %%
#calculates how many times the values are below the threshold for each column

print(r"How many times (% of total) the null hypothesis was rejected for the Granger causality test")
F_test_P_lag_sent_list.extend(F_test_P_lag_ret_list)
ftest_count = results_df.shape[1] - len(F_test_P_lag_sent_list)
count_below = (results_df.iloc[:, ftest_count:] < threshold).sum()
total_count = len(results_df)
percentage_below = round((count_below / (total_count-stationary_failed_count)) * 100,0)
percentage_below_str = percentage_below.astype(int).astype(str) + '%'

print(f"\n{results_df.columns[8].replace('_sum','')}\nSignificance level: {threshold}")
percentage_below_str
# Out:
# How many times (% of total) the null hypothesis was rejected for the Granger causality test
#
# News_positive
# Significance level: 0.01
# F_test_P_lag_sent_1      1%
# F_test_P_lag_sent_2      2%
# F_test_P_lag_sent_3      1%
# F_test_P_lag_sent_4      1%
# F_test_P_lag_sent_5      1%
# F_test_P_lag_sent_6      2%
# F_test_P_lag_sent_7      3%
# F_test_P_lag_sent_8      3%
# F_test_P_lag_sent_9      3%
# F_test_P_lag_sent_10     3%
# F_test_P_ret_sent_1     10%
# F_test_P_ret_sent_2     12%
# F_test_P_ret_sent_3     10%
# F_test_P_ret_sent_4      9%
# F_test_P_ret_sent_5      8%
# F_test_P_ret_sent_6      8%
# F_test_P_ret_sent_7      7%
# F_test_P_ret_sent_8      7%
# F_test_P_ret_sent_9      7%
# F_test_P_ret_sent_10     6%
# dtype: object

# %%
results_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 31 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ticker                500 non-null    object
#  1   Stationarity          500 non-null    object
#  2   News_sum              500 non-null    float64
#  3   News_avg              499 non-null    float64
#  4   News_median           499 non-null    float64
#  5   News_negative_sum     500 non-null    float64
#  6   News_negative_avg     499 non-null    float64
#  7   News_negative_median  499 non-null    float64
#  8   News_positive_sum     500 non-null    float64
#  9   News_positive_avg     499 non-null    float64
#  10  News_positive_median  499 non-null    float64
#  11  F_test_P_lag_sent_1   500 non-null    float64
#  12  F_test_P_lag_sent_2   500 non-null    float64
#  13  F_test_P_lag_sent_3   500 non-null    float64
#  14  F_test_P_lag_sent_4   500 non-null    float64
#  15  F_test_P_lag_sent_5   500 non-null    float64
#  16  F_test_P_lag_sent_6   500 non-null    float64
#  17  F_test_P_lag_sent_7   500 non-null    float64
#  18  F_test_P_lag_sent_8   500 non-null    float64
#  19  F_test_P_lag_sent_9   500 non-null    float64
#  20  F_test_P_lag_sent_10  500 non-null    float64
#  21  F_test_P_ret_sent_1   500 non-null    float64
#  22  F_test_P_ret_sent_2   500 non-null    float64
#  23  F_test_P_ret_sent_3   500 non-null    float64
#  24  F_test_P_ret_sent_4   500 non-null    float64
#  25  F_test_P_ret_sent_5   500 non-null    float64
#  26  F_test_P_ret_sent_6   500 non-null    float64
#  27  F_test_P_ret_sent_7   500 non-null    float64
#  28  F_test_P_ret_sent_8   500 non-null    float64
#  29  F_test_P_ret_sent_9   500 non-null    float64
#  30  F_test_P_ret_sent_10  500 non-null    float64
# dtypes: float64(29), object(2)
# memory usage: 121.2+ KB

# %%
median_list = [[] for _ in range(number_of_charts)]
min_list = [[] for _ in range(number_of_charts)]
max_list = [[] for _ in range(number_of_charts)]
lower_percantage_count=[[] for _ in range(number_of_charts)]

for chart_id, chart_data in enumerate(irf_results[0]):
    for data_list in chart_data:
        
        median_list[chart_id].append(np.median(data_list))
        
        # Calculate percentiles for keeping the central data portion
        lower_percentile = np.percentile(data_list, (1 - keep_value) / 2 * 100)
        upper_percentile = np.percentile(data_list, 100 - (1 - keep_value) / 2 * 100)
        
        # Trim data to keep only the values within the specified percentile range
        trimmed_data = [d for d in data_list if lower_percentile <= d <= upper_percentile]
        
        
        # Append min and max from the trimmed data
        if trimmed_data:  # Check if the list is not empty
            min_list[chart_id].append(np.min(trimmed_data))
            max_list[chart_id].append(np.max(trimmed_data))
        else:
            # Handle the case where trimming leaves the data list empty
            min_list[chart_id].append(np.min(data_list))
            max_list[chart_id].append(np.max(data_list))

#Number of stocks' lower 5% percantage below 0 in every lag:

for chart_id, chart_data in enumerate(irf_results[1]):
    for data_list in chart_data:
        count_below_zero=0
        for num in data_list:
            if num >0:
                count_below_zero += 1
        lower_percantage_count[chart_id].append(count_below_zero/len(data_list))

# print(min_list[:5])
# print(median_list[:5])
# print(max_list[:5])
plt.plot(lower_percantage_count[1])
plt.title("Azon Részvények aránya ahol 95% bizonyosággal modhatjuk hogy pozitív hatás figyelhető meg")
plt.xlabel('Idő')
plt.ylabel('Részvények aránya')
plt.show()

# %%
# Titles for the subplots
titles = [
    'Log Returns Variance → Log Returns Variance',
    'Daily Sentiment Change → Log Returns Variance',
    'Log Returns Variance → Daily Sentiment Change',
    'Daily Sentiment Change → Daily Sentiment Change'
]

# Time points (x-axis values)
time_points = range(len(median_list[0]))

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot the impulse responses with a stronger continuous black line at y=0
for i, ax in enumerate(axs.flatten()):
    ax.plot(time_points, median_list[i], '-b', lw=2)  # Blue line
    ax.set_title(titles[i])
    ax.axhline(0, color='black', linewidth=2, linestyle='-')  # Make the zero line stronger and continuous
    ax.set_xlim([time_points[0], time_points[-1]])  # Set x-axis limits to match modus_list range

# Adjust layout
plt.tight_layout()

# Show the updated plots
plt.show()

# %%
# Time points (x-axis values)
time_points = range(len(median_list[0]))

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot the impulse responses with the specified line styles
for i, ax in enumerate(axs.flatten()):
    ax.plot(time_points, median_list[i], '-b', lw=2)  # Blue solid line for median
    ax.plot(time_points, min_list[i], '--k', lw=1)  # Black dashed line for min
    ax.plot(time_points, max_list[i], '--k', lw=1)  # Black dashed line for max
    ax.set_title(titles[i])
    ax.axhline(0, color='black', linewidth=2, linestyle='-')  # Make the zero line stronger and continuous
    ax.set_xlim([time_points[0], time_points[-1]])  # Set x-axis limits to match the list range

# Adjust layout
plt.tight_layout()

# Show the updated plots
plt.show()

# %%
# Titles for the subplots
titles = [
    'Log Returns Variance → Log Returns Variance',
    'Daily Sentiment Change → Log Returns Variance',
    'Log Returns Variance → Daily Sentiment Change',
    'Daily Sentiment Change → Daily Sentiment Change'
]

cum_median= [np.cumsum(inner_list).tolist() for inner_list in median_list]
# Time points (x-axis values)
time_points = range(len(median_list[0]))

fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# Plot the impulse responses with a stronger continuous black line at y=0
for i, ax in enumerate(axs.flatten()):
    ax.plot(time_points, cum_median[i], '-b', lw=2)  # Blue line
    ax.set_title(titles[i])
    ax.axhline(0, color='black', linewidth=2, linestyle='-')  # Make the zero line stronger and continuous
    ax.axhline(y=np.max(cum_median[i]), color='r', linestyle='--')
    ax.set_xlim([time_points[0], time_points[-1]])  # Set x-axis limits to match modus_list range
    
# Adjust layout
plt.tight_layout()

# Show the updated plots
plt.show()

# %%
# Determens if any of the lags had granger causality at the given threshold
results_df['Granger_true'] = results_df[[*F_test_P_lag_sent_list]].lt(threshold).any(axis=1)
# results_df = results_df[['Ticker', "News_sum","News_avg","News_median", "News_negative_sum","News_negative_avg","News_negative_median", "News_positive_sum","News_positive_avg","News_positive_median",'Granger_true']]
results_df = results_df.drop([*F_test_P_lag_sent_list, *F_test_P_lag_ret_list], axis=1)

# %%
# results_df = pd.merge(results_df, sp500_data, on='Ticker', how='left')
sp500_data = sp500_data.rename(columns={'Ticker': 'Ticker_long'})

sp500_data = sp500_data[:len(results_df)]

results_df = pd.concat([results_df, sp500_data], axis=1)

results_df.head()
# Out:
#   Ticker Stationarity   News_sum     News_avg  News_median  News_negative_sum  \
# 0   MSFT          Yes  1693054.0  1349.047012       1309.0           -13007.0
# 1   AAPL          Yes  2701223.0  2152.368924       2090.0           -34866.0
# 2   NVDA          Yes   486168.0   387.384861        293.0            -7760.0
# 3   AMZN          Yes   766863.0   611.046215        514.0           -17424.0
# 4   GOOG          Yes  1277159.0  1017.656574        919.0           -41667.0
#
#    News_negative_avg  News_negative_median  News_positive_sum  \
# 0         -10.364143                  -4.0            15800.0
# 1         -27.781673                 -17.0            21973.0
# 2          -6.183267                  -2.0            15624.0
# 3         -13.883665                  -8.0            12661.0
# 4         -33.200797                 -17.0             9351.0
#
#    News_positive_avg  News_positive_median  Granger_true     Ticker_long  \
# 0          12.589641                   5.0          True  MSFT UW Equity
# 1          17.508367                   9.0         False  AAPL UW Equity
# 2          12.449402                   4.0          True  NVDA UW Equity
# 3          10.088446                   5.0         False  AMZN UW Equity
# 4           7.450996                   3.0         False  GOOG UW Equity
#
#              Name    Market_cap    Net_income                  Sector
# 0  Microsoft Corp  3.002342e+12  8.254100e+10              Technology
# 1       Apple Inc  2.815209e+12  1.009130e+11              Technology
# 2     NVIDIA Corp  1.793541e+12  1.888800e+10              Technology
# 3  Amazon.com Inc  1.760765e+12  3.042500e+10       Consumer Cyclical
# 4    Alphabet Inc  1.754656e+12  7.379500e+10  Communication Services

# %%
results_df.info()
notebook_name = "mass_analyzer_News_positive_full_period"
results_df.to_csv(notebook_name+ ".csv", index=False)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 17 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Ticker                500 non-null    object
#  1   Stationarity          500 non-null    object
#  2   News_sum              500 non-null    float64
#  3   News_avg              499 non-null    float64
#  4   News_median           499 non-null    float64
#  5   News_negative_sum     500 non-null    float64
#  6   News_negative_avg     499 non-null    float64
#  7   News_negative_median  499 non-null    float64
#  8   News_positive_sum     500 non-null    float64
#  9   News_positive_avg     499 non-null    float64
#  10  News_positive_median  499 non-null    float64
#  11  Granger_true          500 non-null    bool
#  12  Ticker_long           500 non-null    object
#  13  Name                  500 non-null    object
#  14  Market_cap            500 non-null    float64
#  15  Net_income            500 non-null    float64
#  16  Sector                500 non-null    object
# dtypes: bool(1), float64(11), object(5)
# memory usage: 63.1+ KB

# %%
# pd.set_option('display.max_rows', None)


percentage_below_str
# Out:
# F_test_P_lag_sent_1      1%
# F_test_P_lag_sent_2      2%
# F_test_P_lag_sent_3      1%
# F_test_P_lag_sent_4      1%
# F_test_P_lag_sent_5      1%
# F_test_P_lag_sent_6      2%
# F_test_P_lag_sent_7      3%
# F_test_P_lag_sent_8      3%
# F_test_P_lag_sent_9      3%
# F_test_P_lag_sent_10     3%
# F_test_P_ret_sent_1     10%
# F_test_P_ret_sent_2     12%
# F_test_P_ret_sent_3     10%
# F_test_P_ret_sent_4      9%
# F_test_P_ret_sent_5      8%
# F_test_P_ret_sent_6      8%
# F_test_P_ret_sent_7      7%
# F_test_P_ret_sent_8      7%
# F_test_P_ret_sent_9      7%
# F_test_P_ret_sent_10     6%
# dtype: object

# %%
# Set up figure for 1 by 3 subplot layout
fig, axs = plt.subplots(1, 3, figsize=(15, 5))  # Adjust figsize as needed for better display

# From cell_1
time_points = range(len(median_list[0]))
axs[0].plot(time_points, median_list[1], '-b', lw=2)  # Plotting second chart data
axs[0].axhline(0, color='black', linewidth=2, linestyle='-')
axs[0].set_title('Hangulat Index → Hozam variancia változás')
axs[0].set_xlim([time_points[0], time_points[-1]])
axs[0].set_xlabel('Késleltetés (napok)')

# From cell_2 (assuming cum_median is calculated as in cell_2)
cum_median = [np.cumsum(inner_list).tolist() for inner_list in median_list]
axs[1].plot(time_points, cum_median[1], '-b', lw=2)
axs[1].axhline(0, color='black', linewidth=2, linestyle='-')
axs[1].axhline(y=np.max(cum_median[1]), color='r', linestyle='--')
axs[1].set_title('Hangulat Index → Hozam variancia változás')
axs[1].set_xlim([time_points[0], time_points[-1]])
axs[1].set_xlabel('Késleltetés (napok)')

# From cell_3 (assuming lower_percantage_count is calculated as in cell_3)
axs[2].plot(time_points, lower_percantage_count[1], '-g', lw=2)
axs[2].set_title('Pozitív irányú elmozdulások aránya')
axs[2].set_xlabel('Késleltetés (napok)')
axs[2].set_ylabel('Részvények aránya')

# Adjust layout and show the plot
plt.tight_layout()
plt.show()
